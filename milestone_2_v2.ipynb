# %% [markdown]
# # Welcome to our Group Project - Milestone 2 Notebook

# %% [markdown]
# ## Step 0: Environment Setup

# %%
import os, pickle, glob
import pyspark
from pyspark.sql import SparkSession

# %%
sc = SparkSession.builder \
    .config("spark.driver.memory", "10g") \
    .config("spark.executor.memory", "6g") \
    .config('spark.executor.instances', 19) \
    .getOrCreate()

# %% [markdown]
# ## Step 1: Load the dataset - PLEASE SKIP TO STEP 2!

# %% [markdown]
# This section leverages python's gdown library to take in files from Google Drive and upload them into this environment. The files were originally downloaded from huggingface at this link: https://huggingface.co/datasets/BIOMEDICA/biomedica_webdataset_24M/tree/main/noncommercial
#
# The reason for using Google Drive instead of downloading directly from huggingface is because the BIOMEDICA dataset requires sign in and submission of an authorization request before one can access the files, which would complicate API use if another user tried accessing this project file. Instead, downloading the files from huggingface and then uploading them to Google Drive with the sharing setting "anyone with the link can access" makes the files more easily accessible.
#
# With that being said, the data has been loaded, unpacked, and compressed into a parquet file. In order to conserve our computing resources, please DO NOT run the code in this section. You can safely skip ahead to Step 2, where the code will take you through loading the dataset from parquet, which will be faster and less resource-intensive.

# %%
#%pip install gdown
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.11/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from gdown) (3.13.4)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.11/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from gdown) (4.66.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests[socks]->gdown) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.11/site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Installing collected packages: gdown
#   WARNING: The script gdown is installed in '/home/wderoche/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed gdown-5.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import gdown

# This is taking in the google drive file ID for each BIOMEDICA file we want to upload
files = [
    "1GxPYAxUYIhg7h5-9H8NRxOt7Fx0Xx9Zk", # file 000000
    "1XT7jK1YC4T8ElBIemY1BEQPT2LLv70jS", # file 000001
    "1yYMVnCbHzgeVylJZSJ9OdiP4nn2ih4Fv", # file 000002
    "1UD6xTY1xKI8hH1XCEuUPsGC0BFfzDeZr", # file 000003
    "1DxYtwxzMiRAMu8oOqh144upKbOaZBCxi", # file 000004
    "1PxH5jQBoX6QLLml6nRm3-E7fUcYXGAlD", # file 000005
    "1WFRXCWwqe0lCSoHBpBX_7aDM_PPKe_EX", # file 000006
    "14c1hxrR__VEh-xU18lBFRp0MbY1afLak", # file 000007
    "1NUdZXFNbwQP2GEHbjyhGgEn6tk5n0_HT", # file 000008
    "1ctGtFZdxclqr0UHJyc0KuWWisyB-KL15", # file 000009
    "1StBDH91SFSBF2sQS-ulv6051uoKwXv9M", # file 000010
]

for fid in files:
    gdown.download(f"https://drive.google.com/uc?id={fid}", quiet = False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import gdown
#       3 # This is taking in the google drive file ID for each BIOMEDICA file we want to upload
#       4 files = [
#       5     "1GxPYAxUYIhg7h5-9H8NRxOt7Fx0Xx9Zk", # file 000000
#       6     "1XT7jK1YC4T8ElBIemY1BEQPT2LLv70jS", # file 000001
#    (...)
#      15     "1StBDH91SFSBF2sQS-ulv6051uoKwXv9M", # file 000010
#      16 ]
#
# ModuleNotFoundError: No module named 'gdown'

# %% [markdown]
# Now we need to get the image data properly formatted in a Spark RDD

# %%
import os
import tarfile

# Create a directory to extract to
extract_dir = "extracted_images"
os.makedirs(extract_dir, exist_ok = True)

# Extract all .tar files in the current directory
for fname in os.listdir():
    if fname.endswith(".tar"):
        with tarfile.open(fname) as tar:
            tar.extractall(path = extract_dir)

# %% [markdown]
# I had to make a new spark session to continue unpacking and saving because I ran out of time halfway through the process, so this was a check to make sure the files were still available before continuing

# %%
import os

# Check if folder exists
print("Folder exists:", os.path.exists("extracted_images"))

# See how many files are inside
file_count = sum(len(files) for _, _, files in os.walk("extracted_images"))
print("Number of files inside:", file_count)
# Out:
# Folder exists: True
# Number of files inside: 330000

# %%
# sbatch read json individually
# spark.read.json
# try with only 1 .tar file, 1000 .json per
# feed that directory into read_json
# then try 1 .tar, then scale to all

# %%
import os

extract_dir = "extracted_images"
# Get the list of files in the directory
files = os.listdir(extract_dir)

# Print the first file name
if files:
    print(files[0])
# Out:
# filelist_noncommercial_batch_121_13-PMC9621019-2-NSS-14-1927-g0004.json

# %% [markdown]
# Check extracted_images

# %%
extensions = set()
for root, dirs, files in os.walk('extracted_images'):
    for file in files:
        _, ext = os.path.splitext(file)
        extensions.add(ext.lower())  # Get file extension in lowercase

print("File extensions in the directory:", extensions)
# Out:
# File extensions in the directory: {'.json', '.jpg', '.txt'}

# %% [markdown]
# We need to handle each file type separately

# %%
# List of JSON files (sorted)
json_files = sorted(glob.glob("extracted_images/*.json"))

# Load JSON files into a DataFrame
json_df = sc.read.json(json_files)

# %%
# Show the DataFrame schema to check the loaded data - warning this is VERY long
# json_df.printSchema()

# %%
# Show a preview of the data
json_df.show()
# Out:
# +--------------------+--------------------+--------------------+------------+--------------------+--------------------+---------------+--------------------+-----------------------+---------------------+----------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------+-------------------+----------------+-------------------+---------------------+--------------------+----------+
# |    article_abstract|article_accession_id|    article_citation|article_date|     article_journal|    article_keywords|article_license|  article_mesh_terms|article_reference_count|article_reference_ids|article_reference_list|     article_subject|        article_text|       article_title|    image_cluster_id|       image_context|     image_file_name|          image_hash|image_label_id|image_panel_subtype|image_panel_type|image_primary_label|image_secondary_label|           image_set|image_size|
# +--------------------+--------------------+--------------------+------------+--------------------+--------------------+---------------+--------------------+-----------------------+---------------------+----------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------+-------------------+----------------+-------------------+---------------------+--------------------+----------+
# |[{'@Label': 'PURP...|          PMC4338784|Drug Des Devel Th...|  1424160000| Drug Des Devel Ther|["Danusertib","br...|       CC BY-NC|[Comparative Geno...|                     30|                   []|  [{"Citation":"Sta...| [Original Research]|Drug Des Devel Th...|The pan-inhibitor...|    dddt-9-1027Fig10|{NULL, NULL, NULL...|dddt-9-1027Fig10.jpg|d54e7e5bb0aa9a3ff...|             0|       single panel|        multiple|    [Immuno Assays]|         [immunoblot]|[{Danu concentrat...|[744, 348]|
# |[{'@Label': 'PURP...|          PMC4338784|Drug Des Devel Th...|  1424160000| Drug Des Devel Ther|["Danusertib","br...|       CC BY-NC|[Comparative Geno...|                     30|                   []|  [{"Citation":"Sta...| [Original Research]|Drug Des Devel Th...|The pan-inhibitor...|    dddt-9-1027Fig14|{NULL, NULL, NULL...|dddt-9-1027Fig14.jpg|eae47a88fa1b0049b...|             0|       single panel|        multiple|    [Immuno Assays]|         [immunoblot]|[{
|             0|       single panel|        multiple|    [Immuno Assays]|         [immunoblot]|[{Concurrent acti...|[725, 238]|
# |We examined the i...|          PMC6976991|Acta Pharm Sin B....|  1578470400|    Acta Pharm Sin B|                NULL|    CC BY-NC-ND|                  []|                     60|                   []|  [{"Citation":"Kam...|            [Review]|Acta Pharm Sin BA...|Cytochrome P450 e...|                 gr9|{NULL, NULL, NULL...|             gr9.jpg|a3359fc4e1a15934b...|             0|       single panel|        multiple|    [Immuno Assays]|         [immunoblot]|[{Concurrent acti...|[725, 284]|
# |Plant nucleotide-...|          PMC8577132|Plant Commun. 202...|  1629874800|        Plant Commun|["RB","nucleotide...|    CC BY-NC-ND|[Disease Resistan...|                    105|                   []|  [{"Citation":"Ade...|  [Research Article]|pmcPlant CommunPl...|NLR immune recept...|                 gr6|{NULL, NULL, NULL...|             gr6.jpg|41ead210fce07c0d7...|             0|       single panel|        multiple|    [Immuno Assays]|         [immunoblot]|[{IPI-O4 perturbs...|[733, 551]|
# |Arsenic is an env...|          PMC8932518|J Cell Biol. 2022...|  1644393600|         J Cell Biol|                NULL|    CC BY-NC-SA|[Arsenicals, Arse...|                     63|                   []|  [{"Citation":"Abe...|[Article, ["Bioch...|pmcJ Cell BiolJ C...|Differential meta...| JCB_202109034_FigS4|{NULL, NULL, NULL...|JCB_202109034_Fig...|c6b3308c4efcf700b...|             0|       single panel|        multiple|    [Immuno Assays]|         [immunoblot]|[{Acr3 cytoplasmi...|[757, 257]|
# +--------------------+--------------------+--------------------+------------+--------------------+--------------------+---------------+--------------------+-----------------------+---------------------+----------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------+-------------------+----------------+-------------------+---------------------+--------------------+----------+
# only showing top 20 rows

# %%
# Now for the .txt files
txt_files = sorted(glob.glob("extracted_images/*.txt"))
txt_path_str = ",".join(txt_files)
txt_rdd = sc.sparkContext.textFile(txt_path_str)

# %%
# Preview text files
txt_rdd.take(5)
# Out:
# ['Actin and myosin IIA interaction with WIP is independent of WASp. YTS/KIR2DL1 cells were transfected with FLAG-WIP or FLAG-WIPΔ460-503, which is a mutant protein lacking the WASp binding domain. Transfected cells were mixed with 721.221 cells and incubated for the indicated times at 37°C. Cell lysates were immunoprecipitated with anti-FLAG mAb. Immunoprecipitated proteins were immunoblotted with anti–myosin IIA, anti-FLAG, anti-WASp, or anti-actin antibodies. The molecular masses of the proteins according to their position relative to molecular mass markers are shown in parentheses. The absence of WASp does not affect recruitment of either actin or myosin IIA to the complex.',
#  'Syt IV interacts with Stx6. (A) Cell lysates from HEK cells transfected with myc-Stx6 were incubated with GST-Syt IV CD or GST bound to glutathione beads. (B) PC12 cells were lysed in TNTE buffer and incubated with 5 or 10 μg of anti-Stx6 antibody overnight at 4°C, and subsequently bound to protein G beads. Immunoprecipitates and 2.5% of the input were analyzed by immunoblotting with anti–Syt IV antibody. (C) Direct binding of Stx6 to Syt IV in vitro. 3 μg of GST-Syt IV CD bound to glutathione beads was incubated with the indicated amounts of the Stx6 CD in binding buffer overnight, and bound protein was analyzed by immunoblotting with anti-Stx6 antibody 3D10. (D) The Syt IV–Stx6 interaction in vitro is independent of Ca2+. Binding assays were performed as in C, using 1 μM Stx6 CD, supplemented with either 1 mM CaCl2 or 2 mM EGTA.',
#  'Syt IV interacts with Stx6 via both C2A and C2B domains. (A and B) HEK293 cells were cotransfected with HA-Syt IV CD and myc-Stx6. Lysates from untransfected and transfected cells were used for immunoprecipitation with anti-HA (+) or beads alone (−; A) and with anti-myc antibody or beads alone (B). Immunoprecipitates and 10% of total input were analyzed with anti-myc (A) or anti-HA (B) antibodies by immunoblotting. (C and D) Lysates from HEK293 cells cotransfected with either HA-Syt IV C2A or C2B domain and myc-Stx6 were subjected to immunoprecipitation with either anti-myc antibody or beads alone (C), blotted with anti-HA antibody or anti-HA antibody or beads alone (D), and then blotted with anti-myc antibody.',
#  'AKT-mediated phosphorylation of tuberin relieves repression of mTOR-S6K signaling. (A) HEK293 cells were transfected with HA-S6K, Myc-TSC1, and Flag-TSC2 constructs as indicated. Cells were serum starved for 24 h and treated with or without 30 ng/ml IGF-1 for 1 h. Cell lysates were immunoblotted with the indicated antibodies, and phopho-S6K levels were compared with the amount of HA-S6K protein levels. Phospho-AKT (S473) was blotted as a control for the effectiveness of IGF-1 treatment. (B) Western analyses of membrane and cytosolic fractions from HEK293 cells transfected with wild-type or mutant Flag-TSC2 constructs. After 9 h, serum was either removed or allowed to remain for 24 h. The protein levels of phosphorylated endogenous S6K were compared with total S6K protein levels. Phospho-AKT (S473) and phospho-AKT (T308) were blotted as controls for the effectiveness of the indicated treatments.',
#  'Western analysis of Fat1 expression in RASMCs. Cells were serum deprived, stimulated as described, and harvested for protein extraction at the indicated time points. Actin expression is shown as a loading reference. Data are representative of three independent experiments. (A) Induction by 10% FBS for 0–36 h before protein extraction. The blot was also probed for cyclin D1. (B) Induction by specific factors. Cells were stimulated with 10−6 mol/L ATII, 20 ng/ml bFGF, or 20 ng/ml PDGF-BB.']

# %%
# And finally the image data
jpg_files = sorted(glob.glob("extracted_images/*.jpg"))
jpg_path_str = ",".join(jpg_files)
jpg_rdd = sc.sparkContext.binaryFiles(jpg_path_str)

# %%
# Preview one
jpg_rdd.take(1)
# Out:
# [('file:/expanse/lustre/projects/uci150/ntorno/group_project/extracted_images/filelist_noncommercial_batch_0_10-PMC2063796-5-jcb1730121f05.jpg',
#   b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x00\x8b\x01\x90\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xf5\xcdSE{\xbdv\xd2d\xde-%\x18\xbe\x8dH\xdb/\x97\xf3E\xbb\xbf\xde\xceq\xd4pr+&\xe7\xc2\xd0G\x0e\xbb\xf6}\x165\x17\x17\xb0\xb4\x7fe\x8e%v\x84G\x018\x0c6\xb2\xefF%\x0e3\x83\xdc\x8a\xeeh\xa0\x0f;\xfe\xc2\xd6n\xb4\xebh\xa2\xb6\x1a|\x96\xf2\xa7\x90\xf1F\xa3b\xbd\xce\xe7\x7f,\xb3\x05!cC\xb7$\r\xdd?\x846\x7f\x0ejwZ|\x16\x8d`\x8a\xc8!\x8av|J\x932\xdd\xc6\xef)\x0c\xd9`\xca\xac\xe41\xcfPy\xafF\xa2\x80<\xe4\xe87v\xf1\xad\x8c\x9a+\xca\xc6\xeeVk\xbbT\x8dc\x823\xe5\xe1\xa0\x8fp\
# %% [markdown]
# Great! Now we can convert these into dataframes for parquet writing

# %%
# TXT
txt_df = sc.createDataFrame(txt_rdd.map(lambda x: (x,)), ["text"])

# JPG
jpg_df = sc.createDataFrame(jpg_rdd.map(lambda x: (x[0], len(x[1]))), ["file_path", "file_size"])

# %% [markdown]
# Write parquet files

# %%
json_df.write.parquet("parquet_datasets/json_data")

# %%
txt_df.write.parquet("parquet_datasets/text_data")

# %%
jpg_df.write.parquet("parquet_datasets/image_data")

# %% [markdown]
# Redo jpg to address formatting issues

# %%
from pyspark.ml.image import ImageSchema

# Load the images as a DataFrame
image_df = sc.read.format("image").load("extracted_images/*.jpg")

# %%
# Check the schema of the loaded image DataFrame
image_df.printSchema()
# Out:
# root
#  |-- image: struct (nullable = true)
#  |    |-- origin: string (nullable = true)
#  |    |-- height: integer (nullable = true)
#  |    |-- width: integer (nullable = true)
#  |    |-- nChannels: integer (nullable = true)
#  |    |-- mode: integer (nullable = true)
#  |    |-- data: binary (nullable = true)

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import BinaryType
from PIL import Image
import io
from PIL import UnidentifiedImageError

# Define a UDF to resize the image
def resize_image(image_data, target_width=224, target_height=224):
    try:
        img = Image.open(io.BytesIO(image_data))
        img = img.resize((target_width, target_height))
        img_byte_arr = io.BytesIO()
        img.save(img_byte_arr, format='JPEG')
        return img_byte_arr.getvalue()
    except UnidentifiedImageError:
        # Handle invalid image data, e.g., return None or log the error
        return None

# Register the UDF
resize_image = udf(resize_image, BinaryType())

# Apply the UDF to the image DataFrame
resized_df = image_df.withColumn("image_data_resized", resize_image(image_df["image.data"]))

# %%
# Show the resized DataFrame schema
resized_df.printSchema()
# Out:
# root
#  |-- image: struct (nullable = true)
#  |    |-- origin: string (nullable = true)
#  |    |-- height: integer (nullable = true)
#  |    |-- width: integer (nullable = true)
#  |    |-- nChannels: integer (nullable = true)
#  |    |-- mode: integer (nullable = true)
#  |    |-- data: binary (nullable = true)
#  |-- image_data_resized: binary (nullable = true)

# %%
# Preview the resized images
resized_df.select("image.origin", "image.height", "image.width").show(5)
# Out:
# +--------------------+------+-----+
# |              origin|height|width|
# +--------------------+------+-----+
# |file:///expanse/l...|  1920| 1571|
# |file:///expanse/l...|  1800|  714|
# |file:///expanse/l...|  1080|  810|
# |file:///expanse/l...|  2961|  747|
# |file:///expanse/l...|  1200|  791|
# +--------------------+------+-----+
# only showing top 5 rows

# %%
# Update the height and width for the resized images
target_width = 224
target_height = 224

from pyspark.sql.functions import lit

resized_df_with_dimensions = resized_df.withColumn("image.height", lit(target_height)) \
                                        .withColumn("image.width", lit(target_width))

# %%
from pyspark.sql.functions import struct, lit

# Create a new "image" struct with updated height and width
resized_df_with_dimensions = resized_df.withColumn(
    "image", 
    struct(
        "image.origin",
        lit(target_height).alias("height"),
        lit(target_width).alias("width"),
        "image.nChannels",
        "image.mode",
        "image.data"
    )
)

# %%
# Show the updated schema with resized dimensions
resized_df_with_dimensions.printSchema()
# Out:
# root
#  |-- image: struct (nullable = false)
#  |    |-- origin: string (nullable = true)
#  |    |-- height: integer (nullable = false)
#  |    |-- width: integer (nullable = false)
#  |    |-- nChannels: integer (nullable = true)
#  |    |-- mode: integer (nullable = true)
#  |    |-- data: binary (nullable = true)
#  |-- image_data_resized: binary (nullable = true)

# %%
# Preview the updated DataFrame
resized_df_with_dimensions.select("image.origin", "image.height", "image.width").show(5)
# Out:
# +--------------------+------+-----+
# |              origin|height|width|
# +--------------------+------+-----+
# |file:///expanse/l...|   224|  224|
# |file:///expanse/l...|   224|  224|
# |file:///expanse/l...|   224|  224|
# |file:///expanse/l...|   224|  224|
# |file:///expanse/l...|   224|  224|
# +--------------------+------+-----+
# only showing top 5 rows

# %%
# Try writing just a few records to test the pipeline
resized_df_with_dimensions.limit(10).write.mode("overwrite").parquet("parquet_datasets/test_image_data")

# %%
# Now try reading in that file
test_df = sc.read.parquet("parquet_datasets/test_image_data")

# %%
# Check schema
test_df.printSchema()
# Out:
# root
#  |-- image: struct (nullable = true)
#  |    |-- origin: string (nullable = true)
#  |    |-- height: integer (nullable = true)
#  |    |-- width: integer (nullable = true)
#  |    |-- nChannels: integer (nullable = true)
#  |    |-- mode: integer (nullable = true)
#  |    |-- data: binary (nullable = true)
#  |-- image_data_resized: binary (nullable = true)

# %%
# Show the content of the test file to confirm
test_df.select("image").show(10)
# Out:
# +--------------------+
# |               image|
# +--------------------+
# |{file:///expanse/...|
# |{file:///expanse/...|
# |{file:///expanse/...|
# |{file:///expanse/...|
# |{file:///expanse/...|
# |{file:///expanse/...|
# |{file:///expanse/...|
# |{file:///expanse/...|
# |{file:///expanse/...|
# |{file:///expanse/...|
# +--------------------+

# %%
# Ok, that did not work either
from pyspark.sql.functions import udf
from pyspark.sql.types import BinaryType
from PIL import Image
import io

# Define UDF to open, resize, and return image bytes
def resize_image_udf(image_path):
    try:
        # Open the image file
        with Image.open(image_path.replace("file://", "")) as img:
            img = img.convert("RGB")
            img = img.resize((224, 224))
            buffer = io.BytesIO()
            img.save(buffer, format = "JPEG")
            return buffer.getvalue()
    except Exception as e:
        return None

resize_udf = udf(resize_image_udf, BinaryType())

# Apply UDF
resized_df_with_dimensions = image_df.withColumn("image_data_resized", resize_udf("image.origin"))

# %%
# Write again
resized_df_with_dimensions.write.mode("overwrite").parquet("parquet_datasets/test_image_data2")

# %%
# Read again
test_df = sc.read.parquet("parquet_datasets/test_image_data2")
test_df.select("image_data_resized").show(5)
# Out:
# +--------------------+
# |  image_data_resized|
# +--------------------+
# |[FF D8 FF E0 00 1...|
# |[FF D8 FF E0 00 1...|
# |[FF D8 FF E0 00 1...|
# |[FF D8 FF E0 00 1...|
# |[FF D8 FF E0 00 1...|
# +--------------------+
# only showing top 5 rows

# %% [markdown]
# That worked! Now we can use the image data effectively

# %% [markdown]
# ## Step 2: Load dataset and begin investigating

# %% [markdown]
# Beginning with text data

# %%
# Read the text data Parquet file into a DataFrame
txt_df = sc.read.parquet("parquet_datasets/text_data")

# %%
# Check schema
txt_df.printSchema()
# Out:
# root
#  |-- text: string (nullable = true)

# %%
# Check how many entries there are
num_entries = txt_df.count()
print(f"Number of entries: {num_entries}")
# Out:
# Number of entries: 1113

# %%
# Check for null values
from pyspark.sql import functions as F

txt_df.select([F.count(F.when(F.col(c).isNull(), c)).alias(c) for c in txt_df.columns]).show()
# Out:
# +----+
# |text|
# +----+
# |   0|
# +----+

# %% [markdown]
# Now json data

# %%
# Read the JSON data Parquet file into a DataFrame
json_df = sc.read.parquet("parquet_datasets/json_data")

# %%
# Check schema - warning if you run this the output is VERY long
# json_df.printSchema()

# %%
# Check how many entries we have
num_entries = json_df.count()
print(f"Number of entries: {num_entries}")
# Out:
# Number of entries: 897

# %%
json_df.show(1)
# Out:
# +--------------------+--------------------+--------------------+------------+-------------------+--------------------+---------------+--------------------+-----------------------+---------------------+----------------------+-------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+--------------+-------------------+----------------+-------------------+---------------------+--------------------+----------+
# |    article_abstract|article_accession_id|    article_citation|article_date|    article_journal|    article_keywords|article_license|  article_mesh_terms|article_reference_count|article_reference_ids|article_reference_list|    article_subject|        article_text|       article_title|image_cluster_id|       image_context|     image_file_name|          image_hash|image_label_id|image_panel_subtype|image_panel_type|image_primary_label|image_secondary_label|           image_set|image_size|
# +--------------------+--------------------+--------------------+------------+-------------------+--------------------+---------------+--------------------+-----------------------+---------------------+----------------------+-------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+--------------+-------------------+----------------+-------------------+---------------------+--------------------+----------+
# |[{'@Label': 'PURP...|          PMC4338784|Drug Des Devel Th...|  1424160000|Drug Des Devel Ther|["Danusertib","br...|       CC BY-NC|[Comparative Geno...|                     30|                   []|  [{"Citation":"Sta...|[Original Research]|Drug Des Devel Th...|The pan-inhibitor...|dddt-9-1027Fig10|{NULL, NULL, NULL...|dddt-9-1027Fig10.jpg|d54e7e5bb0aa9a3ff...|             0|       single panel|        multiple|    [Immuno Assays]|         [immunoblot]|[{Danu concentrat...|[744, 348]|
# +--------------------+--------------------+--------------------+------------+-------------------+--------------------+---------------+--------------------+-----------------------+---------------------+----------------------+-------------------+--------------------+--------------------+----------------+--------------------+--------------------+--------------------+--------------+-------------------+----------------+-------------------+---------------------+--------------------+----------+
# only showing top 1 row

# %%
# Check what columns we have - this version is easier to read than the printSchema output
print(json_df.columns)
# Out:
# ['article_abstract', 'article_accession_id', 'article_citation', 'article_date', 'article_journal', 'article_keywords', 'article_license', 'article_mesh_terms', 'article_reference_count', 'article_reference_ids', 'article_reference_list', 'article_subject', 'article_text', 'article_title', 'image_cluster_id', 'image_context', 'image_file_name', 'image_hash', 'image_label_id', 'image_panel_subtype', 'image_panel_type', 'image_primary_label', 'image_secondary_label', 'image_set', 'image_size']

# %%
# Find number of unique aritcle titles
unique_titles_count = json_df.select("article_title").distinct().count()
print(f"Number of unique article titles: {unique_titles_count}")
# Out:
# Number of unique article titles: 833

# %%
# View distinct article titles
unique_titles_df = json_df.select('article_title').distinct()

unique_titles_df.show(10)
# Out:
# +--------------------+
# |       article_title|
# +--------------------+
# |Differential meta...|
# |Dynein light chai...|
# |Upregulation of S...|
# |Application of a ...|
# |Polymeric implant...|
# |Cytochrome P450 e...|
# |Escherichia coli ...|
# |Mrd1p binds to pr...|
# |{'@toggle': 'yes'...|
# |Synthesis, Charac...|
# +--------------------+
# only showing top 10 rows

# %%
# Find number of unique image primary labels
unique_image_primary_labels = json_df.select("image_primary_label").distinct().count()
print(f"Number of unique image primary labels: {unique_image_primary_labels}")
# Out:
# Number of unique image primary labels: 1

# %%
# View the primary image label
unique_image_primary = json_df.select("image_primary_label").distinct()

unique_image_primary.show()
# Out:
# +-------------------+
# |image_primary_label|
# +-------------------+
# |    [Immuno Assays]|
# +-------------------+

# %%
# Find number of unique image secondary labels
unique_image_secondary_labels = json_df.select("image_secondary_label").distinct().count()
print(f"Number of unique image secondary labels: {unique_image_secondary_labels}")
# Out:
# Number of unique image secondary labels: 1

# %%
# View the primary image label
unique_image_secondary = json_df.select("image_secondary_label").distinct()

unique_image_secondary.show()
# Out:
# +---------------------+
# |image_secondary_label|
# +---------------------+
# |         [immunoblot]|
# +---------------------+

# %% [markdown]
# And finally the image data

# %%
# Read the image data Parquet file into a DataFrame
image_df = sc.read.parquet("parquet_datasets/test_image_data2")
image_df.show(5)
# Out:
# +--------------------+--------------------+
# |               image|  image_data_resized|
# +--------------------+--------------------+
# |{file:///expanse/...|[FF D8 FF E0 00 1...|
# |{file:///expanse/...|[FF D8 FF E0 00 1...|
# |{file:///expanse/...|[FF D8 FF E0 00 1...|
# |{file:///expanse/...|[FF D8 FF E0 00 1...|
# |{file:///expanse/...|[FF D8 FF E0 00 1...|
# +--------------------+--------------------+
# only showing top 5 rows

# %%
# Check total number of images
print("Total images:", image_df.count())
# Out:
# Total images: 898

# %%
# Show the DataFrame schema to understand the structure
image_df.printSchema()
# Out:
# root
#  |-- image: struct (nullable = true)
#  |    |-- origin: string (nullable = true)
#  |    |-- height: integer (nullable = true)
#  |    |-- width: integer (nullable = true)
#  |    |-- nChannels: integer (nullable = true)
#  |    |-- mode: integer (nullable = true)
#  |    |-- data: binary (nullable = true)
#  |-- image_data_resized: binary (nullable = true)

# %%
# Inspect image data
image_df.select("image.origin", "image.height", "image.width").show(5)
# Out:
# +--------------------+------+-----+
# |              origin|height|width|
# +--------------------+------+-----+
# |file:///expanse/l...|  1920| 1571|
# |file:///expanse/l...|  1800|  714|
# |file:///expanse/l...|  1080|  810|
# |file:///expanse/l...|  2961|  747|
# |file:///expanse/l...|  1200|  791|
# +--------------------+------+-----+
# only showing top 5 rows

# %%
# Decode image data
from PIL import Image
import io
from pyspark.sql import functions as F
from pyspark.sql.functions import udf
from pyspark.sql.types import BooleanType

# Define a function to check if image data is valid
def try_decode_image(content):
    try:
        image = Image.open(io.BytesIO(content))
        image.verify()  # Verify image integrity
        return True
    except:
        return False

# Register the function as a UDF
is_valid_image_udf = udf(try_decode_image, BooleanType())

# %%
# Apply UDF to check validity of each image in image_data_resized column
image_df = image_df.withColumn("is_valid", is_valid_image_udf("image_data_resized"))

# Show some results
image_df.select("image.origin", "is_valid").show(5)
# Out:
# +--------------------+--------+
# |              origin|is_valid|
# +--------------------+--------+
# |file:///expanse/l...|    true|
# |file:///expanse/l...|    true|
# |file:///expanse/l...|    true|
# |file:///expanse/l...|    true|
# |file:///expanse/l...|    true|
# +--------------------+--------+
# only showing top 5 rows

# %%
# Count valid and invalid images
valid_count = image_df.filter(F.col("is_valid") == True).count()
invalid_count = image_df.filter(F.col("is_valid") == False).count()

print(f"Valid images: {valid_count}")
print(f"Corrupt or unreadable images: {invalid_count}")
# Out:
# Valid images: 898
# Corrupt or unreadable images: 0

# %%
# Make a few graphs to visualize the images
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import io

sns.set(style="whitegrid")

# Decode first 5 valid images
sample_images = image_df.select("image.origin", "image_data_resized").limit(5).collect()

# Plot them
plt.figure(figsize=(15, 3))
for i, row in enumerate(sample_images):
    # Decode the image data
    img_data = row["image_data_resized"]
    img = Image.open(io.BytesIO(img_data))
    
    # Convert to numpy array for plotting
    img_array = np.array(img)

    # Plot the image
    plt.subplot(1, 5, i + 1)
    plt.imshow(img_array)
    plt.axis('off')
    plt.title(f"Image {i + 1}")

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 3: Compare with BIOMEDICA parquets from huggingface

# %% [markdown]
# The BIOMEDICA authors have also created some parquet resources to use their database. Now, we will see what that option looks like in terms of dataset size, format, and whether the processing is comparable to our above preprocessing.

# %% [markdown]
# ### PLEASE NOTE: You can skip these next cells as everything has been loaded and downloaded in one parquet for easier use. There will be another note for where you can easily pick back up without re-downloading anything.

# %%
import gdown

# This is taking in the google drive file ID for each BIOMEDICA file we want to upload
parquet_files = [
    "12ZvsKXcPKDo3QWBU3_MH4zKG_mp4AU2q", 
    "1js9jjq6_sED0iCJ7XyYm5nT6OZKnZrB6", 
    "1fvNnt5FFJvl_sDbhDRPmlLqnD5xaU_Eu", 
    "1AuZHBpehRQD_1F2JJZj4OlSnHx39qJwm", 
    "1zPNEXEtESsb1jR4SxFFKAHM6EHwa4aEp", 
    "1h_6aYEHUKoYjsiiSdFjbn0Qjn2KFtd30",
    "1oHvnsmdiBnt2Y2tCHHtLc6IIeORkYs-Z", 
    "1JOAFyfPTA9Ougr6-SIQCT3wGosJOBuHN",
    "1lwsZwRw9kv2KbOFP-64sXyUgts5YbG3F", 
    "19SjlTxWAXjoao9mfpIntShk_qd-4Dlym", 
    "1JYHLj6WynqVl2X2g9zdYHlMqlotyUj61",
    "1_0KtcvJKhLvWRuTCncnHJJB02juVtMO0",
    "108QyrKdDZRbRCxQimd6wNYp-WWtX4hUz",
    "1LLSjw138Uyim3jGDZvJiarntrcdryOOe",
    "1X-BBSszY6n67zchWa6tLC7ZBuo8dN9Yv",
    "1qVukEWT7SmQ7CLVTrSHEUPrFx0bunILx",
    "1jUtSoht5nD5S0GdD3LaDrr7_Nvcr11rT",
    "1LL6oOs0K6serggFaF_GaGw02uDvcylSE",
    "1OXNIaFGcrBMl5i3f_y2j-H_gks5M4Log",
    "1DI66r9ic_zacDwL4jIJww6IG3M6jfx6m",
    "1oGanekYhzt7ZMV72n7tRceNcj1od7eMW",
]

# Download all files
for fid in parquet_files:
    gdown.download(f"https://drive.google.com/uc?id={fid}", quiet=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 30
#      28 # Download all files
#      29 for fid in parquet_files:
# ---> 30     gdown.download(f"https://drive.google.com/uc?id={fid}", quiet=False)
#
# File ~/.local/lib/python3.11/site-packages/gdown/download.py:259, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format, user_agent, log_messages)
#     257     for cookie in sess.cookies:
#     258         cookie_jar.set_cookie(cookie)
# --> 259     cookie_jar.save()
#     261 if "Content-Disposition" in res.headers:
#     262     # This is the file
#     263     break
#
# File /opt/conda/lib/python3.11/http/cookiejar.py:2092, in MozillaCookieJar.save(self, filename, ignore_discard, ignore_expires)
#    2089     if self.filename is not None: filename = self.filename
#    2090     else: raise ValueError(MISSING_FILENAME_TEXT)
# -> 2092 with os.fdopen(
#    2093     os.open(filename, os.O_CREAT | os.O_WRONLY | os.O_TRUNC, 0o600),
#    2094     'w',
#    2095 ) as f:
#    2096     f.write(NETSCAPE_HEADER_TEXT)
#    2097     now = time.time()
#
# KeyboardInterrupt:

# %%
import os

parquet_path = os.path.expanduser('~/ntorno/group_project/train-*.parquet')

# Make dataframe from downloaded files
hf_df = sc.read.parquet(parquet_path)

# %%
hf_df.count()
# Out:
# 34945

# %%
# Write all to a new parquet
hf_df.write.mode('overwrite').parquet('parquet_datasets/biomedica_histopathology')

# %% [markdown]
# ### PLEASE NOTE: You can easily pick up from here without re-downloading data

# %%
hf_df = sc.read.parquet("parquet_datasets/biomedica_histopathology")

# %%
hf_df.show(1)
# Out:
# +--------------------+--------------------+--------------------+----------------+--------------------+--------------------+----------------+-------------------+-------------------+---------------------+----------+--------------------+--------------------+--------------------+--------------------+---------------+------------+--------------------+--------------------+----------+----------+---------------------+-----------------------+----------------------+--------------------+---------------+
# |               image|             caption|            image_id|image_cluster_id|          image_hash|     image_file_name|image_panel_type|image_panel_subtype|image_primary_label|image_secondary_label|image_size|    image_figure_set|       image_context|       article_title|    article_keywords|article_journal|article_date|    article_abstract|  article_mesh_terms|    subset|      pmid|article_reference_ids|article_reference_count|article_reference_list|    article_citation|article_license|
# +--------------------+--------------------+--------------------+----------------+--------------------+--------------------+----------------+-------------------+-------------------+---------------------+----------+--------------------+--------------------+--------------------+--------------------+---------------+------------+--------------------+--------------------+----------+----------+---------------------+-----------------------+----------------------+--------------------+---------------+
# |{[FF D8 FF E0 00 ...|Ultrahigh-content...|41598_2022_5841_F...|              40|8fec9b151d953a171...|41598_2022_5841_F...|        multiple|       single panel|       [Microscopy]| [light microscopy...|[798, 584]|[{'image_id': '41...|{'41598_2022_5841...|MACSima imaging c...|[Biological techn...|        Sci Rep|  1643875200|Many critical adv...|[Biomarkers, Tumo...|commercial|PMC8813936|                   []|                     26|  [{'Citation': 'Sc...|Sci Rep. 2022 Feb...|          CC BY|
# +--------------------+--------------------+--------------------+----------------+--------------------+--------------------+----------------+-------------------+-------------------+---------------------+----------+--------------------+--------------------+--------------------+--------------------+---------------+------------+--------------------+--------------------+----------+----------+---------------------+-----------------------+----------------------+--------------------+---------------+
# only showing top 1 row

# %%
# Check total number of entries
print("Total entries:", hf_df.count())
# Out:
# Total entries: 34945

# %%
# Inspect the schema
hf_df.printSchema()
# Out:
# root
#  |-- image: struct (nullable = true)
#  |    |-- bytes: binary (nullable = true)
#  |    |-- path: string (nullable = true)
#  |-- caption: string (nullable = true)
#  |-- image_id: string (nullable = true)
#  |-- image_cluster_id: string (nullable = true)
#  |-- image_hash: string (nullable = true)
#  |-- image_file_name: string (nullable = true)
#  |-- image_panel_type: string (nullable = true)
#  |-- image_panel_subtype: string (nullable = true)
#  |-- image_primary_label: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- image_secondary_label: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- image_size: array (nullable = true)
#  |    |-- element: integer (containsNull = true)
#  |-- image_figure_set: string (nullable = true)
#  |-- image_context: string (nullable = true)
#  |-- article_title: string (nullable = true)
#  |-- article_keywords: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- article_journal: string (nullable = true)
#  |-- article_date: string (nullable = true)
#  |-- article_abstract: string (nullable = true)
#  |-- article_mesh_terms: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- subset: string (nullable = true)
#  |-- pmid: string (nullable = true)
#  |-- article_reference_ids: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- article_reference_count: string (nullable = true)
#  |-- article_reference_list: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- article_citation: string (nullable = true)
#  |-- article_license: string (nullable = true)

# %%
from PIL import Image
import io
from pyspark.sql.functions import udf
from pyspark.sql.types import BooleanType

# Function to validate image bytes
def try_decode_image(content):
    try:
        image = Image.open(io.BytesIO(content))
        image.verify()
        return True
    except:
        return False

# Register UDF
is_valid_image_udf = udf(try_decode_image, BooleanType())

# %%
# Apply UDF to binary image data
hf_df = hf_df.withColumn("is_valid", is_valid_image_udf("image.bytes"))

# Show path and validity
hf_df.select("image.path", "is_valid").show(5)
# Out:
# +--------------------+--------+
# |                path|is_valid|
# +--------------------+--------+
# |41598_2022_5841_F...|    true|
# |13065_2023_992_Fi...|    true|
# |ANU2023-8627246.0...|    true|
# |jciinsight-6-1478...|    true|
# |zh20101886220004.jpg|    true|
# +--------------------+--------+
# only showing top 5 rows

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import io
import random

# Select a small subset of images 
sample_images = hf_df.select("image.bytes").limit(5).collect()

image_data_list = []

# Collect and convert image bytes into numpy arrays
for row in sample_images:
    img_bytes = row['bytes']
    img = Image.open(io.BytesIO(img_bytes))
    img_array = np.array(img)
    image_data_list.append(img_array)

# Plot the sample images 
fig, axes = plt.subplots(1, 5, figsize = (15, 5))

for ax, img_array in zip(axes, image_data_list):
    ax.imshow(img_array)
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# Key takeaways:
# The structure and content of the BIOMEDICA parquet files are very similar to our exxtracted parquet data. However, it seems that the BIOMEDICA parquet files contain many more entries than the original .tar files used in our preprocessing Step 1. Additionally, the BIOMEDICA parquets have all data for each entry in one schema, whereas our preprocessing created three separate datasets, one for each file type. It may be more efficient to work with the BIOMEDICA parquet data as there are more entries available more easily and in a more concise format.
